# %%
import pandas as pd

df = pd.read_csv('../data/raw/bcn_listings.csv.gz')
df.head()
# Out:
#        id                                               name  host_id  \
# 0   18674    Huge flat for 8 people close to Sagrada Familia    71615
# 1   23197  Forum CCIB DeLuxe, Spacious, Large Balcony, relax    90417
# 2   32711                   Sagrada Familia area - Còrsega 1   135703
# 3   34241   Stylish Top Floor Apartment - Ramblas Plaza Real    73163
# 4  347824  Ideal Happy Location Barceloneta Beach, Old Town!  1447144
#
#                  host_verifications              neighbourhood_cleansed  \
# 0                ['email', 'phone']                  la Sagrada Família
# 1                ['email', 'phone']               el Besòs i el Maresme
# 2  ['email', 'phone', 'work_email']  el Camp d'en Grassot i Gràcia Nova
# 3  ['email', 'phone', 'work_email']                      el Barri Gòtic
# 4                ['email', 'phone']                      la Barceloneta
#
#   neighbourhood_group_cleansed   latitude  longitude        room_type  \
# ...

# %%
from minion.simulation import say_hi

# %%
say_hi("bob")
# Out:
# Hi, bob!
